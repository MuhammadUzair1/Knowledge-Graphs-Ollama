# %%
import os
from dotenv import load_dotenv

env = load_dotenv('config.env')

from src.agents.ontology_explorer import OntologyExplorer
from src.config import LLMConf, EmbedderConf, KnowledgeGraphConfig, ChunkerConf, Source
from src.graph.graph_model import Ontology
from src.ingestion.local_ingestor import LocalIngestor
from src.ingestion.chunker import Chunker
from src.ingestion.cleaner import Cleaner

# %%
DOMAIN_DESCRIPTION = "Press releases and updates from the European Commission"

# %%
source = Source(folder='source_docs')

chunker_conf = ChunkerConf(
    type="recursive", 
    chunk_size=1500, 
    chunk_overlap=0
)

model_conf=LLMConf(
    type=os.getenv("RE_MODEL_TYPE"),
    model=os.getenv("RE_MODEL_NAME"), 
    temperature=os.getenv("RE_MODEL_TEMPERATURE"), 
    deployment=os.getenv("RE_MODEL_DEPLOYMENT"),
    api_key=os.getenv("RE_API_KEY"),
    endpoint=os.getenv("RE_MODEL_ENDPOINT"),
    api_version=os.getenv("RE_MODEL_API_VERSION") or None
)

ingestor = LocalIngestor(source=source)
cleaner = Cleaner()
chunker = Chunker(conf=chunker_conf)

ontology_explorer = OntologyExplorer(
    model_conf, 
    domain_description=DOMAIN_DESCRIPTION
)

# %%
docs = ingestor.batch_ingest()
docs = cleaner.clean_documents(docs)
docs = chunker.chunk_documents(docs)

for i in range(len(docs)):
    print(f"Number of chunks in doc {i}: {len(docs[i].chunks)}")
# Out:
# Number of chunks in doc 0: 6
# Number of chunks in doc 1: 6
# Number of chunks in doc 2: 1

# %%
ontology = ontology_explorer.find_suitable_ontology(docs, pct_chunks=0.5)

# %%
ontology.model_dump()
# Out:
# {'allowed_labels': ['Country',
#   'Payment',
#   'Milestone',
#   'Reform',
#   'Investment',
#   'Policy',
#   'Infrastructure',
#   'Loan',
#   'Disbursement',
#   'Committee',
#   'Regulation',
#   'Mechanism',
#   'Asset',
#   'Revenue',
#   'Facility',
#   'Plan',
#   'Strategy',
#   'Initiative',
#   'Committee Opinion',
#   'Assessment',
#   'Request',
#   'Suspension',
#   'Expenditure',
#   'Infrastructure',
#   'Transport',
#   'Energy',
#   'Water',
#   'Healthcare',
#   'Housing',
#   'Education',
#   'Digitalization',
#   'Climate',
#   'Economy',
#   'Governance',
#   'Security',
#   'Defense',
#   'Aid',
#   'Support',
#   'Repayment',
#   'Profit',
#   'Loss',
#   'Grant',
#   'Allocation',
#   'Implementation',
#   'Monitoring',
#   'Evaluation',
#   'Compliance',
#   'Enforcement',
#   'Amendment',
#   'Termination',
#   'Extension',
#   'Renewal',
#   'Review',
#   'Appeal',
#   'Mediation',
#   'Arbitration',
#   'Litigation',
#   'Settlement',
#   'Enforcement',
#   'Termination',
#   'Extension',
#   'Renewal',
#   'Review',
#   'Appeal',
#   'Mediation',
#   'Arbitration',
#   'Litigation',
#   'Settlement'],
#  'labels_descriptions': {'Country': 'A nation or country involved in the context.',
#   'Payment': 'Financial disbursement or transfer.',
#   'Milestone': 'Key target or achievement in a plan.',
#   'Reform': 'Change or improvement in policies or systems.',
#   'Investment': 'Expenditure of money for specific purposes.',
#   'Policy': 'Course of action or set of principles.',
#   'Infrastructure': "Structures and facilities for a country's needs.",
#   'Loan': 'Sum of money borrowed for specific use.',
#   'Disbursement': 'Act of paying out funds.',
#   'Committee': 'Group of individuals with specific responsibilities.',
#   'Regulation': 'Official rule or law.',
#   'Mechanism': 'System or method of achieving something.',
#   'Asset': 'Resource of value.',
#   'Revenue': 'Income generated.',
#   'Facility': 'Arrangement or resource for a purpose.',
#   'Plan': 'Detailed proposal for doing something.',
#   'Strategy': 'Plan of action designed to achieve a goal.',
#   'Initiative': 'New action or movement toward a goal.',
#   'Committee Opinion': 'Formal judgment by a committee.',
#   'Assessment': 'Evaluation or judgment of something.',
#   'Request': 'Act of asking for something.',
#   'Suspension': 'Temporary stopping of an activity.',
#   'Expenditure': 'Payment or spending of money.',
#   'Transport': 'Movement of goods or people.',
#   'Energy': 'Power or energy systems.',
#   'Water': 'Water resources and management.',
#   'Healthcare': 'Health services and systems.',
#   'Housing': 'Residential buildings and policies.',
#   'Education': 'Institutionalized teaching and learning.',
#   'Digitalization': 'Adoption of digital technologies.',
#   'Climate': 'Climate-related policies and actions.',
#   'Economy': 'System of production and consumption.',
#   'Governance': 'System of rules and practices.',
#   'Security': 'Measures to protect against threats.',
#   'Defense': 'Actions to defend against threats.',
#   'Aid': 'Assistance, especially financial.',
#   'Support': 'Help or assistance provided.',
#   'Repayment': 'Act of paying back a loan.',
#   'Profit': 'Financial gain.',
#   'Loss': 'Financial or other type of loss.',
#   'Grant': 'Funds provided for a specific purpose.',
#   'Allocation': 'Distribution of resources.',
#   'Implementation': 'Process of putting into effect.',
#   'Monitoring': 'Supervision or observation.',
#   'Evaluation': 'Assessment of effectiveness.',
#   'Compliance': 'Adherence to rules or standards.',
#   'Enforcement': 'Act of enforcing compliance.',
#   'Amendment': 'Change or modification.',
#   'Termination': 'End or cancellation.',
#   'Extension': 'Lengthening or prolongation.',
#   'Renewal': 'Process of renewing.',
#   'Review': 'Examination or assessment.',
#   'Appeal': 'Request for reconsideration.',
#   'Mediation': 'Process to resolve disputes.',
#   'Arbitration': 'Resolution by neutral party.',
#   'Litigation': 'Legal process in courts.',
#   'Settlement': 'Agreement to end dispute.'},
#  'allowed_relations': ['SUBMITTED',
#   'APPROVED',
#   'REJECTED',
#   'PENDING',
#   'COMPLETED',
#   'IN_PROGRESS',
#   'ON_HOLD',
#   'CANCELLED',
#   'REIMBURSED',
#   'ALLOCATED',
#   'DISBURSED',
#   'UTILIZED',
#   'MONITORED',
#   'EVALUATED',
#   'COMPLIANT',
#   'NON_COMPLIANT',
#   'ENFORCED',
#   'AMENDED',
#   'TERMINATED',
#   'EXTENDED',
#   'RENEWED',
#   'REVIEWED',
#   'APPEALED',
#   'MEDIATED',
#   'ARBITRATED',
#   'LITIGATED',
#   'SETTLED']}
